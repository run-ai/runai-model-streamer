# %% [markdown]
# # Stream Chunks From File To CPU Memory
#
# In this notebook we are going to read file from the storage in chunks. For example, we will read `Harry Potter and the Sorcerer's Store` book, chapter by chapter, and perform summerization for each chapter, while the rest of the chapters still read from the storage.
#
# ## Preperation
# We will download the book file:

# %%
import subprocess

url = "https://github.com/amephraim/nlp/raw/refs/heads/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt"
local_filename = 'book.txt'

wget_command = ['wget', '--content-disposition', url, '-O', local_filename]
subprocess.run(wget_command, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# Out:
# CompletedProcess(args=['wget', '--content-disposition', "https://github.com/amephraim/nlp/raw/refs/heads/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt", '-O', 'book.txt'], returncode=0, stdout=b'', stderr=b"--2024-10-14 08:31:04--  https://github.com/amephraim/nlp/raw/refs/heads/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt\nResolving github.com (github.com)... 140.82.121.4\nConnecting to github.com (github.com)|140.82.121.4|:443... connected.\nHTTP request sent, awaiting response... 302 Found\nLocation: https://raw.githubusercontent.com/amephraim/nlp/refs/heads/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt [following]\n--2024-10-14 08:31:05--  https://raw.githubusercontent.com/amephraim/nlp/refs/heads/master/texts/J.%20K.%20Rowling%20-%20Harry%20Potter%201%20-%20Sorcerer's%20Stone.txt\nResolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...\nConnecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.\nHTTP request sent, awaiting response... 200 OK\nLength: 439742 (429K) [text/plain]\nSaving to: \xe2\x80\x98book.txt\xe2\x80\x99\n\n     0K .......... .......... .......... .......... .......... 11%  821K 0s\n    50K .......... .......... .......... .......... .......... 23% 2.03M 0s\n   100K .......... .......... .......... .......... .......... 34% 1.25M 0s\n   150K .......... .......... .......... .......... .......... 46% 3.40M 0s\n   200K .......... .......... .......... .......... .......... 58% 4.96M 0s\n   250K .......... .......... .......... .......... .......... 69% 1.52M 0s\n   300K .......... .......... .......... .......... .......... 81% 5.79M 0s\n   350K .......... .......... .......... .......... .......... 93% 4.76M 0s\n   400K .......... .......... .........                       100% 8.74M=0.2s\n\n2024-10-14 08:31:06 (2.07 MB/s) - \xe2\x80\x98book.txt\xe2\x80\x99 saved [439742/439742]\n\n")

# %% [markdown]
# We will now analyze what is the size of each chapter (chunk) and where start the first chapter (file offset)

# %%
def find_chapter_sizes_and_first_index(file_path):
    chapter_sizes = []
    first_index = None
    
    with open(file_path, 'r') as file:
        content = file.read()
        word = "CHAPTER"
        chapter_positions = []
        index = content.find(word)
        
        while index != -1:
            chapter_positions.append(index)
            if first_index is None:
                first_index = index
            index = content.find(word, index + 1)
        
        chapter_positions.append(len(content))

        for i in range(len(chapter_positions) - 1):
            chapter_size = chapter_positions[i + 1] - chapter_positions[i]
            chapter_sizes.append(chapter_size)
    
    return chapter_sizes, first_index

chapter_sizes, first_index = find_chapter_sizes_and_first_index('book.txt')
print(f"First chapter starts at: {first_index}\nChapter sizes: {chapter_sizes}")
# Out:
# First chapter starts at: 40
# Chapter sizes: [25944, 19194, 21584, 20444, 37716, 35069, 25358, 17267, 28284, 24228, 19238, 30799, 18338, 19609, 29024, 36482, 31124]

# %% [markdown]
# ## Streaming
#
# To load the chapters (chunks) from the file we need to create `FileStreamer` instance, perform the request, and start iterating the chapters:

# %%
from runai_model_streamer import FileStreamer

file_path = "book.txt"

def summerize_chapter(buffer, index):
    # Perform heavy computation with the chapter text
    # For example summerize the content
    print(buffer[index:index + 20])
    return

with FileStreamer() as streamer:
    streamer.stream_file(file_path, first_index, chapter_sizes)
    for chapter_index, buffer, buffer_offset in streamer.get_chunks():
        summerize_chapter(buffer, buffer_offset)
# Out:
# [RunAI Streamer] CPU Buffer size: 429.4 KiB for file: book.txt
# b'CHAPTER ONE\n\nTHE BOY'
# b'CHAPTER TWO\n\nTHE VAN'
# b'CHAPTER THREE\n\nTHE L'
# b'CHAPTER FOUR\n\nTHE KE'
# b'CHAPTER FIVE\n\nDIAGON'
# b'CHAPTER SIX\n\nTHE JOU'
# b'CHAPTER SEVEN\n\nTHE S'
# b'CHAPTER EIGHT\n\nTHE P'
# b'CHAPTER NINE\n\nTHE MI'
# b'CHAPTER TEN\n\nHALLOWE'
# b'CHAPTER ELEVEN\n\nQUID'
# b'CHAPTER TWELVE\n\nTHE '
# b'CHAPTER THIRTEEN\n\nNI'
# b'CHAPTER FOURTEEN\n\nNO'
# b'CHAPTER FIFTEEN\n\nTHE'
# Read throughput is b'CHAPTER SIXTEEN\n\nTHR'
# b'CHAPTER SEVENTEEN\n\nT'
# [RunAI Streamer] Overall time to stream 429.4 KiB of all files: 0.0s, 175.1 MiB/s
# 439.70 MB per second

# %% [markdown]
# A heavy workload can be running on each tensor in the moment the tensoe is yielded - as the CPP threads continue reading from the storage.
